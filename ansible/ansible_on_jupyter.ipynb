# %% [markdown]
# # Run the Ansible on Jupyter Notebook x Alpine
#
# - Author: Chu-Siang Lai / chusiang (at) drx.tw
# - GitHub: [chusiang/ansible-jupyter.dockerfile](https://github.com/chusiang/ansible-jupyter.dockerfile)
# - Docker Hub: [chusiang/ansible-jupyter](https://hub.docker.com/r/chusiang/ansible-jupyter/)

# %% [markdown]
# Table of contexts:
# 1. [Operating-System](#Operating-System)
# 1. [Ad-Hoc-commands](#Ad-Hoc-commands)
# 1. [Playbooks](#Playbooks)

# %% [markdown]
# Modified.

# %%
# !ansible all -m whoami
# Out:
# server1 | FAILED! => {
#     "msg": "The module whoami was not found in configured module paths. Additionally, core modules are missing. If this is a checkout, run 'git pull --rebase' to correct this problem."
# }
# server2 | FAILED! => {
#     "msg": "The module whoami was not found in configured module paths. Additionally, core modules are missing. If this is a checkout, run 'git pull --rebase' to correct this problem."
# }
# server3 | FAILED! => {
#     "msg": "The module whoami was not found in configured module paths. Additionally, core modules are missing. If this is a checkout, run 'git pull --rebase' to correct this problem."
# }

# %% [markdown]
# ## Operating System
#
# Check the runtime user.

# %%
# !whoami
# Out:
# root

# %% [markdown]
# Show Linux distribution.

# %%
# !cat /etc/issue
# Out:
# Welcome to Alpine Linux 3.8
# Kernel \r on an \m (\l)

# %% [markdown]
# Workspace.

# %%
# !ls
# Out:
# ansible.cfg               hello.retry               hosts
# ansible_on_jupyter.ipynb  hello.yml                 keys

# %% [markdown]
# Show Python version.

# %%
# !python --version
# Out:
# Python 2.7.15

# %% [markdown]
# Show pip version.

# %%
# !pip --version
# Out:
# pip 18.1 from /usr/lib/python2.7/site-packages/pip (python 2.7)

# %% [markdown]
# Show Ansible version.

# %%
# !ansible --version
# Out:
# ansible 2.7.5
#   config file = /home/ansible.cfg
#   configured module search path = [u'/root/.ansible/plugins/modules', u'/usr/share/ansible/plugins/modules']
#   ansible python module location = /usr/lib/python2.7/site-packages/ansible
#   executable location = /usr/bin/ansible
#   python version = 2.7.15 (default, Aug 16 2018, 14:17:09) [GCC 6.4.0]

# %% [markdown]
# Show Jupyter version.

# %%
# !jupyter --version
# Out:
# 4.4.0

# %% [markdown]
# ## Ansible
#
# Check the playbook syntax, if you see the `[WARNING]`, please fix something, first.

# %%
# !ansible-playbook --syntax-check /home/hello.yml
# Out:
# playbook: /home/hello.yml

# %% [markdown]
# ### Ad-Hoc commands
#
# ping the localhost.

# %%
# !ansible gcp -m ping
# Out:
# 107.167.189.194 | UNREACHABLE! => {
#     "changed": false,
#     "msg": "Failed to connect to the host via ssh: ssh: connect to host 107.167.189.194 port 3288: Operation timed out\r\n",
#     "unreachable": true
# }

# %% [markdown]
# Get the facts with `setup` module.

# %%
# !ansible localhost -m setup
# Out:
# localhost | SUCCESS => {
#     "ansible_facts": {
#         "ansible_all_ipv4_addresses": [],
#         "ansible_all_ipv6_addresses": [],
#         "ansible_apparmor": {
#             "status": "disabled"
#         },
#         "ansible_architecture": "x86_64",
#         "ansible_bios_date": "03/26/2018",
#         "ansible_bios_version": "3602",
#         "ansible_cmdline": {
#             "BOOT_IMAGE": "/boot/vmlinuz-4.19-x86_64",
#             "quiet": true,
#             "root": "UUID=9a415cb1-3b64-4fb7-a037-c6192b57fe95",
#             "rw": true
#         },
#         "ansible_date_time": {
#             "date": "2019-05-10",
#             "day": "10",
#             "epoch": "1557502709",
#             "hour": "15",
#             "iso8601": "2019-05-10T07:38:29Z",
#             "iso8601_basic": "20190510T153829411148",
#             "iso8601_basic_short": "20190510T153829",
#             "iso8601_micro": "2019-05-10T07:38:29.411200Z",
#             "minute": "38",
#             "month": "05",
#             "second": "29",
#             "time": "15:38:29",
#             "tz": "CST",
#             "tz_offset": "+0800",
#             "weekday": "Friday",
#             "weekday_number": "5",
#             "weeknumber": "18",
#             "year": "2019"
#         },
#         "ansible_default_ipv4": {
#             "address": "172.18.0.4",
#             "gateway": "172.18.0.1",
#             "interface": "eth0"
#         },
#         "ansible_default_ipv6": {},
#         "ansible_device_links": {
#             "ids": {},
#             "labels": {},
#             "masters": {},
#             "uuids": {}
#         },
#         "ansible_devices": {
#             "loop0": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "mq-deadline",
#                 "sectors": "357128",
#                 "sectorsize": "512",
#                 "size": "174.38 MB",
#                 "support_discard": "4096",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop1": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "mq-deadline",
#                 "sectors": "356288",
#                 "sectorsize": "512",
#                 "size": "173.97 MB",
#                 "support_discard": "4096",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop2": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "mq-deadline",
#                 "sectors": "267408",
#                 "sectorsize": "512",
#                 "size": "130.57 MB",
#                 "support_discard": "4096",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop3": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "mq-deadline",
#                 "sectors": "183272",
#                 "sectorsize": "512",
#                 "size": "89.49 MB",
#                 "support_discard": "4096",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop4": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "mq-deadline",
#                 "sectors": "270624",
#                 "sectorsize": "512",
#                 "size": "132.14 MB",
#                 "support_discard": "4096",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop5": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "mq-deadline",
#                 "sectors": "186360",
#                 "sectorsize": "512",
#                 "size": "91.00 MB",
#                 "support_discard": "4096",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop6": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "mq-deadline",
#                 "sectors": "355528",
#                 "sectorsize": "512",
#                 "size": "173.60 MB",
#                 "support_discard": "4096",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "loop7": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": null,
#                 "partitions": {},
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "mq-deadline",
#                 "sectors": "183240",
#                 "sectorsize": "512",
#                 "size": "89.47 MB",
#                 "support_discard": "4096",
#                 "vendor": null,
#                 "virtual": 1
#             },
#             "sda": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": "GALAX TA1D0120A",
#                 "partitions": {
#                     "sda1": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [],
#                             "masters": [],
#                             "uuids": []
#                         },
#                         "sectors": "1021952",
#                         "sectorsize": 512,
#                         "size": "499.00 MB",
#                         "start": "2048",
#                         "uuid": null
#                     },
#                     "sda2": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [],
#                             "masters": [],
#                             "uuids": []
#                         },
#                         "sectors": "204800",
#                         "sectorsize": 512,
#                         "size": "100.00 MB",
#                         "start": "1024000",
#                         "uuid": null
#                     },
#                     "sda3": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [],
#                             "masters": [],
#                             "uuids": []
#                         },
#                         "sectors": "32768",
#                         "sectorsize": 512,
#                         "size": "16.00 MB",
#                         "start": "1228800",
#                         "uuid": null
#                     },
#                     "sda4": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [],
#                             "masters": [],
#                             "uuids": []
#                         },
#                         "sectors": "121620480",
#                         "sectorsize": 512,
#                         "size": "57.99 GB",
#                         "start": "1261568",
#                         "uuid": null
#                     },
#                     "sda5": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [],
#                             "masters": [],
#                             "uuids": []
#                         },
#                         "sectors": "111559567",
#                         "sectorsize": 512,
#                         "size": "53.20 GB",
#                         "start": "122882048",
#                         "uuid": null
#                     }
#                 },
#                 "removable": "0",
#                 "rotational": "0",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "mq-deadline",
#                 "sectors": "234441648",
#                 "sectorsize": "512",
#                 "size": "111.79 GB",
#                 "support_discard": "512",
#                 "vendor": "ATA",
#                 "virtual": 1
#             },
#             "sdb": {
#                 "holders": [],
#                 "host": "",
#                 "links": {
#                     "ids": [],
#                     "labels": [],
#                     "masters": [],
#                     "uuids": []
#                 },
#                 "model": "WDC WD10EZEX-08W",
#                 "partitions": {
#                     "sdb1": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [],
#                             "masters": [],
#                             "uuids": []
#                         },
#                         "sectors": "838864896",
#                         "sectorsize": 512,
#                         "size": "400.00 GB",
#                         "start": "4096",
#                         "uuid": null
#                     },
#                     "sdb2": {
#                         "holders": [],
#                         "links": {
#                             "ids": [],
#                             "labels": [],
#                             "masters": [],
#                             "uuids": []
#                         },
#                         "sectors": "1114656143",
#                         "sectorsize": 512,
#                         "size": "531.51 GB",
#                         "start": "838868992",
#                         "uuid": null
#                     }
#                 },
#                 "removable": "0",
#                 "rotational": "1",
#                 "sas_address": null,
#                 "sas_device_handle": null,
#                 "scheduler_mode": "mq-deadline",
#                 "sectors": "1953525168",
#                 "sectorsize": "512",
#                 "size": "931.51 GB",
#                 "support_discard": "0",
#                 "vendor": "ATA",
#                 "virtual": 1
#             }
#         },
#         "ansible_distribution": "Alpine",
#         "ansible_distribution_file_parsed": true,
#         "ansible_distribution_file_path": "/etc/alpine-release",
#         "ansible_distribution_file_variety": "Alpine",
#         "ansible_distribution_major_version": "NA",
#         "ansible_distribution_release": "NA",
#         "ansible_distribution_version": "3.8.2",
#         "ansible_dns": {
#             "nameservers": [
#                 "127.0.0.11"
#             ],
#             "options": {
#                 "ndots": "0"
#             }
#         },
#         "ansible_domain": "",
#         "ansible_effective_group_id": 0,
#         "ansible_effective_user_id": 0,
#         "ansible_env": {
#             "CLICOLOR": "1",
#             "GIT_PAGER": "cat",
#             "HOME": "/root",
#             "HOSTNAME": "5867f3d0e7e2",
#             "JPY_PARENT_PID": "6",
#             "MPLBACKEND": "module://ipykernel.pylab.backend_inline",
#             "PAGER": "cat",
#             "PATH": "/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin",
#             "PWD": "/home",
#             "SHLVL": "4",
#             "TERM": "xterm-color"
#         },
#         "ansible_eth0": {
#             "active": true,
#             "device": "eth0",
#             "macaddress": "02:42:ac:12:00:04",
#             "mtu": 1500,
#             "promisc": false,
#             "speed": 10000,
#             "type": "ether"
#         },
#         "ansible_fips": false,
#         "ansible_form_factor": "Desktop",
#         "ansible_fqdn": "5867f3d0e7e2",
#         "ansible_hostname": "5867f3d0e7e2",
#         "ansible_interfaces": [
#             "lo",
#             "eth0"
#         ],
#         "ansible_is_chroot": false,
#         "ansible_iscsi_iqn": "",
#         "ansible_kernel": "4.19.14-1-MANJARO",
#         "ansible_lo": {
#             "active": true,
#             "device": "lo",
#             "mtu": 65536,
#             "promisc": false,
#             "type": "loopback"
#         },
#         "ansible_local": {},
#         "ansible_lsb": {},
#         "ansible_machine": "x86_64",
#         "ansible_memfree_mb": 5543,
#         "ansible_memory_mb": {
#             "nocache": {
#                 "free": 10004,
#                 "used": 5968
#             },
#             "real": {
#                 "free": 5543,
#                 "total": 15972,
#                 "used": 10429
#             },
#             "swap": {
#                 "cached": 0,
#                 "free": 0,
#                 "total": 0,
#                 "used": 0
#             }
#         },
#         "ansible_memtotal_mb": 15972,
#         "ansible_mounts": [
#             {
#                 "block_available": 115181848,
#                 "block_size": 4096,
#                 "block_total": 136882607,
#                 "block_used": 21700759,
#                 "device": "/dev/sdb2",
#                 "fstype": "ext4",
#                 "inode_available": 34635214,
#                 "inode_total": 34840576,
#                 "inode_used": 205362,
#                 "mount": "/home",
#                 "options": "rw,relatime",
#                 "size_available": 471784849408,
#                 "size_total": 560671158272,
#                 "uuid": "N/A"
#             },
#             {
#                 "block_available": 115181848,
#                 "block_size": 4096,
#                 "block_total": 136882607,
#                 "block_used": 21700759,
#                 "device": "/dev/sdb2",
#                 "fstype": "ext4",
#                 "inode_available": 34635214,
#                 "inode_total": 34840576,
#                 "inode_used": 205362,
#                 "mount": "/etc/ansible",
#                 "options": "rw,relatime",
#                 "size_available": 471784849408,
#                 "size_total": 560671158272,
#                 "uuid": "N/A"
#             },
#             {
#                 "block_available": 1459324,
#                 "block_size": 4096,
#                 "block_total": 13660341,
#                 "block_used": 12201017,
#                 "device": "/dev/sda5",
#                 "fstype": "ext4",
#                 "inode_available": 2511125,
#                 "inode_total": 3489792,
#                 "inode_used": 978667,
#                 "mount": "/etc/localtime",
#                 "options": "ro,noatime,discard",
#                 "size_available": 5977391104,
#                 "size_total": 55952756736,
#                 "uuid": "N/A"
#             },
#             {
#                 "block_available": 1459324,
#                 "block_size": 4096,
#                 "block_total": 13660341,
#                 "block_used": 12201017,
#                 "device": "/dev/sda5",
#                 "fstype": "ext4",
#                 "inode_available": 2511125,
#                 "inode_total": 3489792,
#                 "inode_used": 978667,
#                 "mount": "/etc/resolv.conf",
#                 "options": "rw,noatime,discard",
#                 "size_available": 5977391104,
#                 "size_total": 55952756736,
#                 "uuid": "N/A"
#             },
#             {
#                 "block_available": 1459324,
#                 "block_size": 4096,
#                 "block_total": 13660341,
#                 "block_used": 12201017,
#                 "device": "/dev/sda5",
#                 "fstype": "ext4",
#                 "inode_available": 2511125,
#                 "inode_total": 3489792,
#                 "inode_used": 978667,
#                 "mount": "/etc/hostname",
#                 "options": "rw,noatime,discard",
#                 "size_available": 5977391104,
#                 "size_total": 55952756736,
#                 "uuid": "N/A"
#             },
#             {
#                 "block_available": 1459324,
#                 "block_size": 4096,
#                 "block_total": 13660341,
#                 "block_used": 12201017,
#                 "device": "/dev/sda5",
#                 "fstype": "ext4",
#                 "inode_available": 2511125,
#                 "inode_total": 3489792,
#                 "inode_used": 978667,
#                 "mount": "/etc/hosts",
#                 "options": "rw,noatime,discard",
#                 "size_available": 5977391104,
#                 "size_total": 55952756736,
#                 "uuid": "N/A"
#             }
#         ],
#         "ansible_nodename": "5867f3d0e7e2",
#         "ansible_os_family": "Alpine",
#         "ansible_pkg_mgr": "apk",
#         "ansible_processor": [
#             "0",
#             "GenuineIntel",
#             "Intel(R) Core(TM) i7-4770 CPU @ 3.40GHz",
#             "1",
#             "GenuineIntel",
#             "Intel(R) Core(TM) i7-4770 CPU @ 3.40GHz",
#             "2",
#             "GenuineIntel",
#             "Intel(R) Core(TM) i7-4770 CPU @ 3.40GHz",
#             "3",
#             "GenuineIntel",
#             "Intel(R) Core(TM) i7-4770 CPU @ 3.40GHz",
#             "4",
#             "GenuineIntel",
#             "Intel(R) Core(TM) i7-4770 CPU @ 3.40GHz",
#             "5",
#             "GenuineIntel",
#             "Intel(R) Core(TM) i7-4770 CPU @ 3.40GHz",
#             "6",
#             "GenuineIntel",
#             "Intel(R) Core(TM) i7-4770 CPU @ 3.40GHz",
#             "7",
#             "GenuineIntel",
#             "Intel(R) Core(TM) i7-4770 CPU @ 3.40GHz"
#         ],
#         "ansible_processor_cores": 4,
#         "ansible_processor_count": 1,
#         "ansible_processor_threads_per_core": 2,
#         "ansible_processor_vcpus": 8,
#         "ansible_product_name": "All Series",
#         "ansible_product_serial": "System Serial Number",
#         "ansible_product_uuid": "c05a2b2b-6d93-697c-791b-049226ce9ccc",
#         "ansible_product_version": "System Version",
#         "ansible_python": {
#             "executable": "/usr/bin/python2",
#             "has_sslcontext": true,
#             "type": "CPython",
#             "version": {
#                 "major": 2,
#                 "micro": 15,
#                 "minor": 7,
#                 "releaselevel": "final",
#                 "serial": 0
#             },
#             "version_info": [
#                 2,
#                 7,
#                 15,
#                 "final",
#                 0
#             ]
#         },
#         "ansible_python_version": "2.7.15",
#         "ansible_real_group_id": 0,
#         "ansible_real_user_id": 0,
#         "ansible_selinux": {
#             "status": "Missing selinux Python library"
#         },
#         "ansible_selinux_python_present": false,
#         "ansible_service_mgr": "docker-entrypoi",
#         "ansible_swapfree_mb": 0,
#         "ansible_swaptotal_mb": 0,
#         "ansible_system": "Linux",
#         "ansible_system_vendor": "ASUS",
#         "ansible_uptime_seconds": 24352,
#         "ansible_user_dir": "/root",
#         "ansible_user_gecos": "root",
#         "ansible_user_gid": 0,
#         "ansible_user_id": "root",
#         "ansible_user_shell": "/bin/ash",
#         "ansible_user_uid": 0,
#         "ansible_userspace_architecture": "x86_64",
#         "ansible_userspace_bits": "64",
#         "ansible_virtualization_role": "guest",
#         "ansible_virtualization_type": "docker",
#         "gather_subset": [
#             "all"
#         ],
#         "module_setup": true
#     },
#     "changed": false
# }

# %% [markdown]
# Remove the **vim** with apk package management on **Alpine**.

# %%
# !ansible localhost -m apk -a 'name=vim state=absent'
# Out:
# localhost | SUCCESS => {
#     "changed": true,
#     "msg": "removed vim package(s)",
#     "packages": [
#         "vim",
#         "lua5.2-libs"
#     ],
#     "stderr": "",
#     "stderr_lines": [],
#     "stdout": "(1/2) Purging vim (8.0.1359-r0)\n(2/2) Purging lua5.2-libs (5.2.4-r4)\nExecuting busybox-1.27.2-r7.trigger\nOK: 274 MiB in 61 packages\n",
#     "stdout_lines": [
#         "(1/2) Purging vim (8.0.1359-r0)",
#         "(2/2) Purging lua5.2-libs (5.2.4-r4)",
#         "Executing busybox-1.27.2-r7.trigger",
#         "OK: 274 MiB in 61 packages"
#     ]
# }

# %% [markdown]
# Install the **vim** with apk package management on **Alpine**.

# %%
# !ansible localhost -m apk -a 'name=vim state=present'
# Out:
# localhost | SUCCESS => {
#     "changed": true,
#     "msg": "installed vim package(s)",
#     "packages": [
#         "lua5.2-libs",
#         "vim"
#     ],
#     "stderr": "",
#     "stderr_lines": [],
#     "stdout": "(1/2) Installing lua5.2-libs (5.2.4-r4)\n(2/2) Installing vim (8.0.1359-r0)\nExecuting busybox-1.27.2-r7.trigger\nOK: 300 MiB in 63 packages\n",
#     "stdout_lines": [
#         "(1/2) Installing lua5.2-libs (5.2.4-r4)",
#         "(2/2) Installing vim (8.0.1359-r0)",
#         "Executing busybox-1.27.2-r7.trigger",
#         "OK: 300 MiB in 63 packages"
#     ]
# }

# %% [markdown]
# Install the **tree** with apk package management on **Alpine**.

# %%
# !ansible localhost -m apk -a 'name=tree state=present'
# Out:
# localhost | SUCCESS => {
#     "changed": true,
#     "msg": "installed tree package(s)",
#     "packages": [
#         "tree"
#     ],
#     "stderr": "",
#     "stderr_lines": [],
#     "stdout": "(1/1) Installing tree (1.7.0-r1)\nExecuting busybox-1.27.2-r7.trigger\nOK: 300 MiB in 64 packages\n",
#     "stdout_lines": [
#         "(1/1) Installing tree (1.7.0-r1)",
#         "Executing busybox-1.27.2-r7.trigger",
#         "OK: 300 MiB in 64 packages"
#     ]
# }

# %%
# !tree .
# Out:
# .
# ├── ansible.cfg
# ├── ansible_on_jupyter.ipynb
# ├── inventory
# └── setup_jupyter.yml
#
# 0 directories, 4 files

# %% [markdown]
# ## Playbooks
#
# Show `setup_jupyter.yml` playbook.

# %%
# !cat setup_jupyter.yml
# Out:
# ---
#
# - name: "Setup Ansible-Jupyter"
#   hosts: localhost
#
#   vars:
#
#     # General package on GNU/Linux.
#     general_packages:
#       - bash
#       - bash-completion
#       - ca-certificates
#       - curl
#       - git
#       - openssl
#       - sshpass
#
#     # Alpine Linux.
#     apk_packages:
#       - openssh-client
#       - vim
#
#     # Debian, Ubuntu.
#     apt_packages: "{{ apk_packages }}"
#
#     # Arch Linux.
#     pacman_packages:
#       - openssh
#       - vim
#
#     # Gentoo Linux.
#     portage_packages:
#       - bash
#       - bash-completion
#       - ca-certificates
#       - dev-vcs/git
#       - net-misc/curl
#       - openssh
#       - openssl
#       - sqlite
#       - vim
#
#     # CentOS.
#     yum_packages:
#       - openssh-clients
#       - vim-minimal
#
#     # openSUSE.
#     zypper_packages: "{{ pacman_packages }}"
#
#     # Python.
#     pip_packages:
#       - docker-py
#       - docker-compose
#
#     jupyter_notebook_config_py_url: "https://raw.githubusercontent.com/chusiang/ansible-jupyter.dockerfile/master/files/jupyter_notebook_config.py"
#     ssh_private_key_url: "https://raw.githubusercontent.com/chusiang/ansible-jupyter.dockerfile/master/files/ssh/id_rsa"
#     ansible_cfg_url: "https://raw.githubusercontent.com/chusiang/ansible-jupyter.dockerfile/master/ansible.cfg"
#     inventory_url: "https://raw.githubusercontent.com/chusiang/ansible-jupyter.dockerfile/master/inventory"
#
#   tasks:
#
#     - name: Install necessary packages of Linux
#       block:
#
#         - name: Install general linux packages
#           package:
#             name: "{{ item }}"
#             state: present
#           with_items: "{{ general_packages }}"
#           when:
#             - general_packages is defined
#             - ansible_pkg_mgr != "portage"
#
#         - name: Install apk packages on Alpine Linux
#           apk:
#             name: "{{ item }}"
#             state: present
#           with_items: "{{ apk_packages }}"
#           when:
#             - apk_packages is defined
#             - ansible_pkg_mgr == "apk"
#
#         - name: Install apt packages on Debian and Ubuntu
#           apt:
#             name: "{{ item }}"
#             state: present
#           with_items: "{{ apt_packages }}"
#           when:
#             - apt_packages is defined
#             - ansible_pkg_mgr == "apt"
#
#         - name: Install pacman packages on Arch Linux
#           pacman:
#             name: "{{ item }}"
#             state: present
#           with_items: "{{ pacman_packages }}"
#           when:
#             - pacman_packages is defined
#             - ansible_pkg_mgr == "pacman"
#
#         - name: Install portage packages on Gentoo Linux
#           portage:
#             package: "{{ item }}"
#             state: present
#           with_items:
#            - "{{ portage_packages }}"
#           when:
#             - portage_packages is defined
#             - ansible_pkg_mgr == "portage"
#
#         - name: Install yum packages on CentOS
#           yum:
#             name: "{{ item }}"
#             state: present
#           with_items: "{{ yum_packages }}"
#           when:
#             - yum_packages is defined
#             - ansible_pkg_mgr == "yum"
#
#         - name: Install zypper packages on openSUSE
#           zypper:
#             name: "{{ item }}"
#             state: present
#           with_items: "{{ zypper_packages }}"
#           when:
#             - zypper_packages is defined
#             - ansible_pkg_mgr == "zypper"
#
#     - name: Install necessary packages of Python
#       block:
#
#         - name: Install general pip packages
#           pip:
#             name: "{{ item }}"
#             state: present
#           with_items: "{{ pip_packages }}"
#           when: pip_packages is defined
#
#         - name: Install pysqlite on gentoo
#           pip:
#             name: pysqlite
#             state: present
#           when:
#             - ansible_pkg_mgr == "portage"
#
#         - name: Upgrade six
#           pip:
#             name: six
#             state: latest
#           tags: skip_ansible_lint
#
#     - name: Install and configuration Jupyter (application)
#       block:
#
#         - name: Install jupyter
#           pip:
#             name: jupyter
#             version: 1.0.0
#             state: present
#
#         # Disable jupyter authentication token. (1/2)
#         - name: Create `/root/.jupyter` directory
#           file:
#             path: /root/.jupyter
#             state: directory
#             mode: 0700
#
#         # Disable jupyter authentication token. (2/2)
#         - name: Get jupyter_notebook_config.py
#           get_url:
#             url: "{{ jupyter_notebook_config_py_url }}"
#             dest: /root/.jupyter/jupyter_notebook_config.py
#             mode: 0644
#             checksum: md5:c663914a24281ddf10df6bc9e7238b07
#
#     - name: Integrate Ansible and Jupyter
#       block:
#
#         - name: Create `/root/.ssh` directory
#           file:
#             path: /root/.ssh
#             state: directory
#             mode: 0700
#
#         - name: Get ssh private key
#           get_url:
#             url: "{{ ssh_private_key_url }}"
#             dest: /root/.ssh/id_rsa
#             mode: 0600
#             checksum: md5:6cc26e77bf23a9d72a51b22387bea61f
#
#         - name: Get ansible.cfg file
#           get_url:
#             url: "{{ ansible_cfg_url }}"
#             dest: /home/
#             mode: 0644
#
#         - name: Get inventory file
#           get_url:
#             url: "{{ inventory_url }}"
#             dest: /home/
#             mode: 0644
#
# # vim: ft=yaml.ansible :

# %% [markdown]
# Run the `setup_jupyter.yml` playbook.

# %%
# !ansible-playbook setup_jupyter.yml
# Out:
# ERROR! the playbook: setup_jupyter.yml could not be found

# %% [markdown]
# Enjoy it !

# %% [markdown]
# ## Reference
#
# * [怎麼用 Jupyter 操控 Ansible？(localhost) | 現代 IT 人一定要知道的 Ansible 自動化組態技巧](https://chusiang.gitbooks.io/automate-with-ansible/07.how-to-practive-the-ansible-with-jupyter1.html)
# * [常用的 Ansible Module 有哪些？ | 現代 IT 人一定要知道的 Ansible 自動化組態技巧](https://chusiang.gitbooks.io/automate-with-ansible/12.which-are-the-commonly-used-modules.html)
# * [怎麼看 Ansible Modules 文件？ | 現代 IT 人一定要知道的 Ansible 自動化組態技巧](https://chusiang.gitbooks.io/automate-with-ansible/11.how-to-see-the-ansible-module-document.html)
